# %% [markdown]
# # Hypocalcémie

# %% [markdown]
# Voici le programme à compléter en lien avec l'exercice sur l'hypocalcémie.

# %% [markdown]
# Tout d'abord, il faut importer les bibliothèques utiles au programme.

# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# Il faut entrer les valeurs expérimentales comme dans un tableur (variable x pour les abscisses et y pour les ordonnées).

# %%
x = [10.0,7.5,5.0,2.5,1.0]#Ci en mmol/L
y = [5.88,4.41,2.94,1.47,0.59]#G en mS

# %% [markdown]
# Il faut définir l'affichage des grandeurs et des axes.

# %%
plt.title("Courbe d'étalonnage G = f(C)")
plt.xlabel("C (mmol/L)")
plt.ylabel("G (ms)")
plt.plot(x,y,"bo",label="points expérimentaux")
plt.axis(xmin=0,xmax=10,ymin=0,ymax=6)
plt.grid(linestyle="-.")
plt.xticks(range(11))
# Out:
# ([<matplotlib.axis.XTick at 0x7fb4b3ff6c50>,
#   <matplotlib.axis.XTick at 0x7fb4b4013a10>,
#   <matplotlib.axis.XTick at 0x7fb4b3ff6310>,
#   <matplotlib.axis.XTick at 0x7fb482717f50>,
#   <matplotlib.axis.XTick at 0x7fb48272c510>,
#   <matplotlib.axis.XTick at 0x7fb48272c110>,
#   <matplotlib.axis.XTick at 0x7fb48272ccd0>,
#   <matplotlib.axis.XTick at 0x7fb4806b6250>,
#   <matplotlib.axis.XTick at 0x7fb4806b6790>,
#   <matplotlib.axis.XTick at 0x7fb4806b6110>,
#   <matplotlib.axis.XTick at 0x7fb4806be210>],
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %% [markdown]
# Il faut à présent réaliser la modélisation graphique.

# %%
modele=np.polyfit(x,y,1)
xm=np.linspace(0, 10,10)
ym=modele[0]*xm+modele[1]
plt.plot(xm, ym, "r-", label="modele y="+str(round(modele[0],3))+r"$\times x_m + $"+str(round(modele[1],3)))
print("Coefficient directeur du modele" + str(round(modele[0],3)))
print("Ordonnée à l'origine du modèle" + str(round(modele[1],3)))
plt.legend()
plt.show()
# Out:
# Coefficient directeur du modele0.588
# Ordonnée à l'origine du modèle0.001

# %% [markdown]
# L'équation est disponible au dessus de la courbe.
