# %% [markdown]
# # Somme de signaux sinusoïdaux

# %%
from pylab import*
x = linspace(0, 2*pi, 30)
y1 = sin(x)
y2 = sin(x + 3*pi/2)
y3 = y1 + y2
plot (x, y1, label = "sin(x)")
plot (x, y2, label = "sin(x + dephasage)")
plot (x, y3, label = "sin(x) + sin(x + dephasage)")
legend()
show()
